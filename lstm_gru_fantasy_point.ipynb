# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, LSTM, GRU, Input, Concatenate, Reshape


data = pd.read_csv('data.csv')


label_enc = LabelEncoder()
data['Player Role'] = label_enc.fit_transform(data['Player Role'])
data['Team'] = label_enc.fit_transform(data['Team'])

features = ['Batting Average', 'Bowling Average', 'Strike Rate', 'Economy Rate', 
            'Centuries Scored', 'Half Centuries Scored', 'Ducks Scored', 
            'Wickets Taken Last Match', 'Runs Scored Last Match', 
            'Player Age', 'Player Experience', 'Player Role', 'Team']

X = data[features]
y = data[['Runs Scored', 'Wickets Taken', 'Balls Faced', 'Balls Bowled', 
          'Overs Bowled', 'Maidens Bowled', 'Runs Conceded']]


for col in y.columns:
    y[col] = y[col] / data['Player Experience']

scaler_X = StandardScaler()
scaler_y = StandardScaler()
X_scaled = scaler_X.fit_transform(X)
y_scaled = scaler_y.fit_transform(y)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.2, random_state=42)
# Out:
# WARNING:tensorflow:From c:\Users\shoya\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# C:\Users\shoya\AppData\Local\Temp\ipykernel_10172\1919140137.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[col] = y[col] / data['Player Experience']

# %%
def create_model(input_shape):
    input_layer = Input(shape=(input_shape,))
    
    reshaped_input = Reshape((input_shape, 1))(input_layer)
    
    lstm = LSTM(64, return_sequences=True)(reshaped_input)
    lstm = LSTM(32)(lstm)
    
    gru = GRU(64, return_sequences=True)(reshaped_input)
    gru = GRU(32)(gru)
    
    concat = Concatenate()([lstm, gru])
    
    dense1 = Dense(64, activation='relu')(concat)
    dense2 = Dense(32, activation='relu')(dense1)
    
    output = Dense(7)(dense2)  
    
    model = Model(inputs=input_layer, outputs=output)
    model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])
    
    return model


model = create_model(X_train.shape[1])
model.fit(X_train, y_train, epochs=50, batch_size=4, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 6/6 [==============================] - 12s 455ms/step - loss: 1.0001 - mae: 0.7296 - val_loss: 1.0081 - val_mae: 0.7458
# Epoch 2/50
# 6/6 [==============================] - 0s 25ms/step - loss: 0.9828 - mae: 0.7204 - val_loss: 1.0059 - val_mae: 0.7472
# Epoch 3/50
# 6/6 [==============================] - 0s 27ms/step - loss: 0.9676 - mae: 0.7133 - val_loss: 1.0004 - val_mae: 0.7524
# Epoch 4/50
# 6/6 [==============================] - 0s 24ms/step - loss: 0.9499 - mae: 0.7032 - val_loss: 0.9934 - val_mae: 0.7564
# Epoch 5/50
# 6/6 [==============================] - 0s 24ms/step - loss: 0.9246 - mae: 0.6867 - val_loss: 0.9804 - val_mae: 0.7555
# Epoch 6/50
# 6/6 [==============================] - 0s 24ms/step - loss: 0.9012 - mae: 0.6700 - val_loss: 0.9586 - val_mae: 0.7569
# Epoch 7/50
# 6/6 [==============================] - 0s 25ms/step - loss: 0.8854 - mae: 0.6541 - val_loss: 0.9497 - val_mae: 0.7325
# Epoch 8/50
# 6/6 [==============================] - 0s 23ms/step - loss: 0.8497 - mae: 0.6318 - val_loss: 0.9289 - val_mae: 0.7286
# Epoch 9/50
# 6/6 [==============================] - 0s 24ms/step - loss: 0.8222 - mae: 0.6111 - val_loss: 0.9188 - val_mae: 0.7187
# Epoch 10/50
# 6/6 [==============================] - 0s 24ms/step - loss: 0.7962 - mae: 0.5894 - val_loss: 0.9291 - val_mae: 0.6949
# Epoch 11/50
# 6/6 [==============================] - 0s 24ms/step - loss: 0.7841 - mae: 0.5800 - val_loss: 0.9824 - val_mae: 0.6850
# Epoch 12/50
# 6/6 [==============================] - 0s 32ms/step - loss: 0.7372 - mae: 0.5497 - val_loss: 0.9234 - val_mae: 0.6840
# Epoch 13/50
# 6/6 [==============================] - 0s 25ms/step - loss: 0.7465 - mae: 0.5464 - val_loss: 0.9318 - val_mae: 0.6644
# Epoch 14/50
# 6/6 [==============================] - 0s 25ms/step - loss: 0.6881 - mae: 0.5228 - val_loss: 1.0104 - val_mae: 0.6789
# Epoch 15/50
# 6/6 [==============================] - 0s 27ms/step - loss: 0.6765 - mae: 0.5176 - val_loss: 1.0013 - val_mae: 0.6667
# Epoch 16/50
# 6/6 [==============================] - 0s 29ms/step - loss: 0.6504 - mae: 0.5014 - val_loss: 0.9779 - val_mae: 0.6499
# Epoch 17/50
# 6/6 [==============================] - 0s 24ms/step - loss: 0.6284 - mae: 0.4920 - val_loss: 0.9802 - val_mae: 0.6452
# Epoch 18/50
# 6/6 [==============================] - 0s 24ms/step - loss: 0.6092 - mae: 0.4881 - val_loss: 0.9654 - val_mae: 0.6334
# Epoch 19/50
# 6/6 [==============================] - 0s 32ms/step - loss: 0.5961 - mae: 0.4938 - val_loss: 0.9546 - val_mae: 0.6322
# Epoch 20/50
# 6/6 [==============================] - 0s 28ms/step - loss: 0.5581 - mae: 0.4771 - val_loss: 1.0308 - val_mae: 0.6556
# Epoch 21/50
# 6/6 [==============================] - 0s 32ms/step - loss: 0.5420 - mae: 0.4723 - val_loss: 1.0006 - val_mae: 0.6494
# Epoch 22/50
# 6/6 [==============================] - 0s 30ms/step - loss: 0.5123 - mae: 0.4566 - val_loss: 0.9120 - val_mae: 0.6091
# Epoch 23/50
# 6/6 [==============================] - 0s 29ms/step - loss: 0.4938 - mae: 0.4483 - val_loss: 0.9228 - val_mae: 0.6101
# Epoch 24/50
# 6/6 [==============================] - 0s 24ms/step - loss: 0.4698 - mae: 0.4405 - val_loss: 1.0126 - val_mae: 0.6467
# Epoch 25/50
# 6/6 [==============================] - 0s 28ms/step - loss: 0.4568 - mae: 0.4425 - val_loss: 0.9854 - val_mae: 0.6368
# Epoch 26/50
# 6/6 [==============================] - 0s 27ms/step - loss: 0.4391 - mae: 0.4336 - val_loss: 0.9729 - val_mae: 0.6367
# Epoch 27/50
# 6/6 [==============================] - 0s 28ms/step - loss: 0.3792 - mae: 0.3867 - val_loss: 0.9533 - val_mae: 0.6305
# Epoch 28/50
# 6/6 [==============================] - 0s 43ms/step - loss: 0.3940 - mae: 0.4137 - val_loss: 0.9800 - val_mae: 0.6461
# Epoch 29/50
# 6/6 [==============================] - 0s 26ms/step - loss: 0.3511 - mae: 0.3849 - val_loss: 0.9841 - val_mae: 0.6493
# Epoch 30/50
# 6/6 [==============================] - 0s 25ms/step - loss: 0.2947 - mae: 0.3578 - val_loss: 1.1355 - val_mae: 0.6848
# Epoch 31/50
# 6/6 [==============================] - 0s 24ms/step - loss: 0.2698 - mae: 0.3371 - val_loss: 1.1479 - val_mae: 0.7146
# Epoch 32/50
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2356 - mae: 0.3232 - val_loss: 1.1028 - val_mae: 0.6978
# Epoch 33/50
# 6/6 [==============================] - 0s 24ms/step - loss: 0.2079 - mae: 0.3117 - val_loss: 1.2589 - val_mae: 0.7437
# Epoch 34/50
# 6/6 [==============================] - 0s 24ms/step - loss: 0.1930 - mae: 0.2937 - val_loss: 1.1745 - val_mae: 0.7304
# Epoch 35/50
# 6/6 [==============================] - 0s 22ms/step - loss: 0.1688 - mae: 0.2782 - val_loss: 1.3743 - val_mae: 0.7595
# Epoch 36/50
# 6/6 [==============================] - 0s 23ms/step - loss: 0.1454 - mae: 0.2556 - val_loss: 1.4405 - val_mae: 0.7843
# Epoch 37/50
# 6/6 [==============================] - 0s 22ms/step - loss: 0.1181 - mae: 0.2315 - val_loss: 1.4610 - val_mae: 0.7929
# Epoch 38/50
# 6/6 [==============================] - 0s 23ms/step - loss: 0.1098 - mae: 0.2261 - val_loss: 1.5123 - val_mae: 0.8167
# Epoch 39/50
# 6/6 [==============================] - 0s 23ms/step - loss: 0.1056 - mae: 0.2155 - val_loss: 1.5151 - val_mae: 0.8204
# Epoch 40/50
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0863 - mae: 0.2085 - val_loss: 1.5009 - val_mae: 0.8117
# Epoch 41/50
# 6/6 [==============================] - 0s 26ms/step - loss: 0.0829 - mae: 0.1977 - val_loss: 1.6037 - val_mae: 0.8451
# Epoch 42/50
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0768 - mae: 0.1896 - val_loss: 1.6695 - val_mae: 0.8597
# Epoch 43/50
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0690 - mae: 0.1797 - val_loss: 1.6146 - val_mae: 0.8629
# Epoch 44/50
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0664 - mae: 0.1699 - val_loss: 1.6225 - val_mae: 0.8567
# Epoch 45/50
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0624 - mae: 0.1577 - val_loss: 1.7048 - val_mae: 0.8684
# Epoch 46/50
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0593 - mae: 0.1610 - val_loss: 1.6060 - val_mae: 0.8495
# Epoch 47/50
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0637 - mae: 0.1586 - val_loss: 1.6548 - val_mae: 0.8613
# Epoch 48/50
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0719 - mae: 0.1691 - val_loss: 1.6665 - val_mae: 0.8681
# Epoch 49/50
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0491 - mae: 0.1478 - val_loss: 1.5948 - val_mae: 0.8535
# Epoch 50/50
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0447 - mae: 0.1437 - val_loss: 1.6331 - val_mae: 0.8366

# %%
def calculate_fantasy_points(row, match_type):
    points = 0
    
    
    points += 4  
    points += row['Runs Scored']
    points += row['Wickets Taken'] * 25 if match_type != 'Test' else row['Wickets Taken'] * 16
    
    
    if row['Runs Scored'] == 0 and row['Balls Faced'] > 0:
        points -= 2 if match_type in ['T20', 'T10'] else 3 if match_type == 'ODI' else 4
    
    
    if row['Runs Scored'] >= 50:
        points += 8 if match_type == 'T20' else 4 if match_type in ['ODI', 'Test'] else 16
    if row['Runs Scored'] >= 100:
        points += 16 if match_type == 'T20' else 8
    
    if row['Maidens Bowled'] > 0:
        points += row['Maidens Bowled'] * (12 if match_type == 'T20' else 4 if match_type == 'ODI' else 16)
    
    if row['Wickets Taken'] >= 4:
        points += 8 if match_type == 'T20' else 4
    if row['Wickets Taken'] >= 5:
        points += 16 if match_type == 'T20' else 8
    
    
    if row['Overs Bowled'] >= 2:
        economy_rate = row['Runs Conceded'] / row['Overs Bowled']
        if economy_rate < 6:
            points += 4
        elif economy_rate > 9:
            points -= 2
    
    return points


X_all_scaled = scaler_X.transform(X)
predicted_stats_scaled = model.predict(X_all_scaled)
predicted_stats = scaler_y.inverse_transform(predicted_stats_scaled)
# Out:
# 1/1 [==============================] - 3s 3s/step

# %%
predicted_df = pd.DataFrame(predicted_stats, columns=y.columns)
predicted_df['Player Name'] = data['Player Name']
predicted_df['Team'] = data['Team']
predicted_df['Player Role'] = data['Player Role']

for col in y.columns:
    if col in ['Runs Scored', 'Balls Faced', 'Balls Bowled', 'Runs Conceded']:
        predicted_df[col] = predicted_df[col].round().astype(int)
    elif col in ['Wickets Taken', 'Maidens Bowled']:
        predicted_df[col] = predicted_df[col].round(1)
    elif col == 'Overs Bowled':
        predicted_df[col] = predicted_df[col].round(1)

# %%
match_type = 'ODI'  
predicted_df['Predicted Fantasy Points'] = predicted_df.apply(lambda row: calculate_fantasy_points(row, match_type), axis=1)

def select_top_11_with_roles(df):
    sorted_players = df.sort_values(by='Predicted Fantasy Points', ascending=False)
    
    team = []
    roles_covered = set()
    
    for _, player in sorted_players.iterrows():
        if len(team) >= 11 and len(roles_covered) == len(label_enc.classes_):
            break
        if player['Player Role'] not in roles_covered or len(team) < 11:
            team.append(player)
            roles_covered.add(player['Player Role'])
    
    while len(team) < 11:
        for _, player in sorted_players.iterrows():
            if player not in team:
                team.append(player)
                break
    
    return pd.DataFrame(team)

# %%
top_players = select_top_11_with_roles(predicted_df)

print("Top 11 Players based on Predicted Fantasy Points:")
print(top_players[['Player Name', 'Team', 'Predicted Fantasy Points', 'Player Role']])

print("\nPredicted Stats for Top Players (per match):")
print(top_players[['Player Name', 'Runs Scored', 'Wickets Taken', 'Balls Faced', 'Balls Bowled', 
                   'Overs Bowled', 'Maidens Bowled', 'Runs Conceded']])


role_distribution = top_players['Player Role'].value_counts()
print(role_distribution)
# Out:
# Top 11 Players based on Predicted Fantasy Points (with role validation):
#            Player Name  Team  Predicted Fantasy Points  Player Role
# 20        Shreyas Iyer     0                185.000000            2
# 16        Sanju Samson     0                170.000000            2
# 18     Janith Liyanage     1                 71.500000            2
# 27       Kuldeep Yadav     0                 70.500001            2
# 6    Washington Sundar     0                 63.400001            3
# 12     Pathum Nissanka     1                 61.000000            0
# 5         Shubman Gill     0                 52.000000            0
# 0          Virat Kohli     0                 48.000000            0
# 1         Rohit Sharma     0                 48.000000            0
# 28      Mohammed Siraj     0                 47.500001            2
# 2         Rishabh Pant     0                 47.500000            2
# 14  Maheesh Theekshana     1                 22.900000            1
#
# Predicted Stats for Top Players (per match):
#            Player Name  Runs Scored  Wickets Taken  Balls Faced  Balls Bowled  \
# 20        Shreyas Iyer          169            0.0          164             1
# 16        Sanju Samson          149            0.2          145             8
# 18     Janith Liyanage           57            0.1           64            15
# 27       Kuldeep Yadav           35            1.1           31            29
# 6    Washington Sundar           19            1.2            9            41
# 12     Pathum Nissanka           53           -0.0           63            -4
# 5         Shubman Gill           48           -0.0           48             3
# 0          Virat Kohli           44            0.0           48             0
# 1         Rohit Sharma           44           -0.0           47            -1
# 28      Mohammed Siraj            0            1.7            3            52
# 2         Rishabh Pant           41            0.1           55             1
# 14  Maheesh Theekshana           -1            0.7            3            37
#
#     Overs Bowled  Maidens Bowled  Runs Conceded
# 20           0.5            -0.0              2
# 16           1.5             0.0              4
# 18           2.4             0.0              8
# 27           4.9            -0.0             28
# 6            7.1             1.6             30
# 12           0.4            -0.1              6
# 5           -0.1            -0.0              1
# 0            0.0            -0.1              4
# 1           -0.2            -0.1              3
# 28           8.5             0.0             43
# 2            0.5            -0.0              1
# 14           6.0             0.6             36
# Player Role
# 2    6
# 0    4
# 3    1
# 1    1
# Name: count, dtype: int64
